# %%
# Cell 1: Настройка путей, импорт и загрузка функций инференса
import os
import sys
import glob
import random

import torch
import cv2
import numpy as np
import pandas as pd
from pathlib import Path

# Корень проекта — две папки выше текущего рабочего каталога
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Путь до папки custom_inference, чтобы Python видел yolo_inference
inference_dir = os.path.join(project_root, 'custom_inference')
if inference_dir not in sys.path:
    sys.path.insert(0, inference_dir)

# Импортируем наш модуль инференса для YOLO
import yolo_inference  # он должен лежать в ./custom_inference/yolo_inference.py

# Пути к моделям
MODEL_DIR = os.path.join(inference_dir, 'models', 'yolo')
model_path_1 = os.path.join(MODEL_DIR, 'best.pt')
model_path_2 = os.path.join(MODEL_DIR, 'yolo12m.pt')

# Пути к данным для оценки (датасет YOLO с images/ и labels/ + data.yaml)
YOLO_DATA_DIR = os.path.join(project_root, 'dataset', 'yolo')
IMAGES_DIR = os.path.join(YOLO_DATA_DIR, 'images/val')
LABELS_DIR = os.path.join(YOLO_DATA_DIR, 'labels/val')

print("Cell 1: Импорт выполнен, пути установлены. Ready to proceed.")
# Out:
# Cell 1: Импорт выполнен, пути установлены. Ready to proceed.

# %%
# Cell 2: Сбор списка изображений и их аннотаций, выбор случайного поднабора
# Соберём все файлы с расширением .jpg или .png в папке images
image_extensions = ('*.jpg', '*.jpeg', '*.png')
all_image_paths = []
for ext in image_extensions:
    all_image_paths.extend(glob.glob(os.path.join(IMAGES_DIR, ext)))
all_image_paths = sorted(all_image_paths)

# Проверим, что для каждого изображения существует соответствующий .txt в labels
def get_label_path(img_path):
    """
    По пути к изображению формирует путь до соответствующего .txt-файла с аннотациями.
    Предполагается, что структура папок images/… и labels/… совпадает, а расширение меняется на .txt.
    """
    rel = os.path.relpath(img_path, IMAGES_DIR)
    base, _ = os.path.splitext(rel)
    label_path = os.path.join(LABELS_DIR, base + '.txt')
    return label_path

# Отфильтруем только те изображения, у которых есть .txt
validated_image_paths = []
for img_path in all_image_paths:
    if os.path.isfile(get_label_path(img_path)):
        validated_image_paths.append(img_path)

# Если данных слишком много, выберем случайную подвыборку, например 500 изображений
random.seed(42)
sample_size = 500
if len(validated_image_paths) > sample_size:
    sampled_image_paths = random.sample(validated_image_paths, sample_size)
else:
    sampled_image_paths = validated_image_paths.copy()

print(f"Всего изображений с аннотациями: {len(validated_image_paths)}")
print(f"Будем использовать в сравнении: {len(sampled_image_paths)} (случайная подвыборка)")
# Out:
# Всего изображений с аннотациями: 1583
# Будем использовать в сравнении: 500 (случайная подвыборка)

# %%
# Cell 3: Вспомогательные функции для чтения GT и вычисления IoU
def load_ground_truth(label_path, img_width, img_height):
    """
    Считывает YOLO-формат аннотаций из .txt и возвращает список GT-боксов в виде
    [class_id, x_min, y_min, x_max, y_max].
    """
    gt_boxes = []
    with open(label_path, 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls_id = int(parts[0])
            x_center = float(parts[1]) * img_width
            y_center = float(parts[2]) * img_height
            w = float(parts[3]) * img_width
            h = float(parts[4]) * img_height
            x_min = x_center - w / 2
            y_min = y_center - h / 2
            x_max = x_center + w / 2
            y_max = y_center + h / 2
            gt_boxes.append([cls_id, x_min, y_min, x_max, y_max])
    return gt_boxes

def compute_iou(box1, box2):
    """
    box = [x_min, y_min, x_max, y_max]
    Возвращает IoU двух прямоугольников.
    """
    x_left = max(box1[0], box2[0])
    y_top = max(box1[1], box2[1])
    x_right = min(box1[2], box2[2])
    y_bottom = min(box1[3], box2[3])

    if x_right < x_left or y_bottom < y_top:
        return 0.0

    intersection_area = (x_right - x_left) * (y_bottom - y_top)
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union_area = box1_area + box2_area - intersection_area

    if union_area <= 0:
        return 0.0
    return intersection_area / union_area

# %%
# Cell 4: Функции для метрик (Precision, Recall, AP, mAP на IoU=0.5)
def prepare_detection_lists(all_gt, all_preds, iou_threshold=0.5):
    """
    all_gt: dict: ключ = image_id, значение = список GT-боксов [class_id, x_min, y_min, x_max, y_max]
    all_preds: dict: ключ = image_id, значение = список предсказаний [class_id, confidence, x_min, y_min, x_max, y_max]

    Возвращает словари по классам:
    gt_by_class: {class_id: list of dict(image_id, bbox, used=False)}
    det_by_class: {class_id: list of dict(image_id, bbox, confidence)}
    """
    gt_by_class = {}
    det_by_class = {}

    # GT
    for img_id, gt_list in all_gt.items():
        for item in gt_list:
            cls_id, x_min, y_min, x_max, y_max = item
            if cls_id not in gt_by_class:
                gt_by_class[cls_id] = []
            gt_by_class[cls_id].append({'image_id': img_id,
                                        'bbox': [x_min, y_min, x_max, y_max],
                                        'used': False})

    # Предсказания
    for img_id, pred_list in all_preds.items():
        for item in pred_list:
            cls_id = item['class_id']
            conf = item['confidence']
            x_min, y_min, w, h = item['box']
            x_max = x_min + w
            y_max = y_min + h
            if cls_id not in det_by_class:
                det_by_class[cls_id] = []
            det_by_class[cls_id].append({'image_id': img_id,
                                         'bbox': [x_min, y_min, x_max, y_max],
                                         'confidence': conf})
    return gt_by_class, det_by_class

def calculate_ap_per_class(gt_entries, pred_entries, iou_threshold=0.5):
    """
    gt_entries: список словарей {'image_id', 'bbox', 'used': False}
    pred_entries: список словарей {'image_id', 'bbox', 'confidence'}
    Возвращает AP для одного класса.
    """
    # Сортируем предсказания по убыванию confidence
    pred_entries = sorted(pred_entries, key=lambda x: x['confidence'], reverse=True)
    tp = np.zeros(len(pred_entries))
    fp = np.zeros(len(pred_entries))

    n_positives = len(gt_entries)

    # Создадим словарь с GT по изображению для удобства
    gt_per_img = {}
    for idx, g in enumerate(gt_entries):
        img_id = g['image_id']
        if img_id not in gt_per_img:
            gt_per_img[img_id] = []
        gt_per_img[img_id].append({'bbox': g['bbox'], 'used': False})

    for idx, pred in enumerate(pred_entries):
        img_id = pred['image_id']
        pred_box = pred['bbox']
        max_iou = 0.0
        max_gt_idx = -1

        if img_id in gt_per_img:
            for gt_idx, gt in enumerate(gt_per_img[img_id]):
                if not gt['used']:
                    iou = compute_iou(pred_box, gt['bbox'])
                    if iou > max_iou:
                        max_iou = iou
                        max_gt_idx = gt_idx

        if max_iou >= iou_threshold and max_gt_idx >= 0:
            tp[idx] = 1
            gt_per_img[img_id][max_gt_idx]['used'] = True
        else:
            fp[idx] = 1

    # Накопительное суммирование
    cum_tp = np.cumsum(tp)
    cum_fp = np.cumsum(fp)
    recalls = cum_tp / (n_positives + 1e-6)
    precisions = cum_tp / (cum_tp + cum_fp + 1e-6)

    # Добавим точку (0,1) в начало
    recalls = np.concatenate(([0.0], recalls, [1.0]))
    precisions = np.concatenate(([1.0], precisions, [0.0]))

    # Коррекция precision: для точек справа налево
    for i in range(len(precisions) - 2, -1, -1):
        precisions[i] = max(precisions[i], precisions[i + 1])

    # Найдём индексы, где recall меняет значение
    idxs = np.where(recalls[1:] != recalls[:-1])[0]
    ap = 0.0
    for idx in idxs:
        ap += (recalls[idx + 1] - recalls[idx]) * precisions[idx + 1]
    return ap

def compute_map(all_gt, all_preds, iou_threshold=0.5):
    """
    all_gt, all_preds: словари с ключом = image_id, значением = список GT или предсказаний.
    Возвращает dict: {class_id: AP}, mAP (среднее по классам)
    """
    gt_by_class, det_by_class = prepare_detection_lists(all_gt, all_preds, iou_threshold)
    ap_per_class = {}
    for cls_id in gt_by_class.keys():
        gt_entries = gt_by_class.get(cls_id, [])
        pred_entries = det_by_class.get(cls_id, [])
        ap = calculate_ap_per_class(gt_entries, pred_entries, iou_threshold)
        ap_per_class[cls_id] = ap

    # Учтём классы, которые предсказываются, но отсутствуют в GT (AP = 0)
    for cls_id in det_by_class.keys():
        if cls_id not in ap_per_class:
            ap_per_class[cls_id] = 0.0

    # mAP
    if len(ap_per_class) > 0:
        mAP = np.mean(list(ap_per_class.values()))
    else:
        mAP = 0.0

    return ap_per_class, mAP

# %%
# Cell 5: Загрузка моделей
# Предполагаются следующие функции в yolo_inference:
#   load_model(path_to_weights) → возвращает объект модели
#   inference(model, image) → возвращает список детекций в формате:
#       [{'class_id': int, 'confidence': float, 'box': [x_min, y_min, width, height]}, ...]
model1 = yolo_inference.load_model(model_path_1)
model2 = yolo_inference.load_model(model_path_2)

print("Cell 5: Модели загружены:")
print(f"  Model 1: {model_path_1}")
print(f"  Model 2: {model_path_2}")
# Out:
# Cell 5: Модели загружены:
#   Model 1: c:\Users\thjat\ml-system-design-aith\custom_inference\models\yolo\best.pt
#   Model 2: c:\Users\thjat\ml-system-design-aith\custom_inference\models\yolo\yolo12m.pt

# %%
# Cell 6: Сбор GT и предсказаний на подвыборке
all_gt = {}      # ключ: image_id (строка пути), значение: список GT-боксов
all_preds_1 = {} # ключ: image_id, значение: список предсказаний от модели1
all_preds_2 = {} # аналогично для модели2

for img_path in sampled_image_paths:
    img_id = os.path.relpath(img_path, project_root)
    # Считываем изображение
    img = cv2.imread(img_path)
    h, w = img.shape[:2]

    # Загружаем GT
    label_path = get_label_path(img_path)
    gt_boxes = load_ground_truth(label_path, w, h)
    all_gt[img_id] = gt_boxes

    # Запускаем инференс первой модели
    preds1 = yolo_inference.inference(model1, img)
    all_preds_1[img_id] = preds1

    # Запускаем инференс второй модели
    preds2 = yolo_inference.inference(model2, img)
    all_preds_2[img_id] = preds2

print("Cell 6: Инференс на подвыборке выполнен.")
print(f"  Количество изображений: {len(all_gt)}")
# Out:
# 0: 384x640 1 kilometer_post, 284.4ms
# Speed: 2.3ms preprocess, 284.4ms inference, 5.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 238.4ms
# Speed: 1.1ms preprocess, 238.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 271.0ms
# Speed: 1.8ms preprocess, 271.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 275.7ms
# Speed: 1.6ms preprocess, 275.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 245.6ms
# Speed: 2.3ms preprocess, 245.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 236.4ms
# Speed: 1.4ms preprocess, 236.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 263.2ms
# Speed: 1.2ms preprocess, 263.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.8ms
# Speed: 1.2ms preprocess, 242.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 240.2ms
# Speed: 1.0ms preprocess, 240.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.3ms
# Speed: 0.9ms preprocess, 239.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 236.6ms
# Speed: 1.6ms preprocess, 236.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.5ms
# Speed: 1.8ms preprocess, 246.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 272.3ms
# Speed: 4.0ms preprocess, 272.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 231.1ms
# Speed: 1.4ms preprocess, 231.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 241.1ms
# Speed: 1.9ms preprocess, 241.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 240.2ms
# Speed: 1.3ms preprocess, 240.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 picket_posts, 231.5ms
# Speed: 1.2ms preprocess, 231.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.2ms
# Speed: 0.9ms preprocess, 251.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 235.2ms
# Speed: 2.2ms preprocess, 235.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.2ms
# Speed: 2.3ms preprocess, 251.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 229.4ms
# Speed: 1.1ms preprocess, 229.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.5ms
# Speed: 1.0ms preprocess, 244.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.9ms
# Speed: 1.2ms preprocess, 253.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.5ms
# Speed: 0.8ms preprocess, 244.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 235.2ms
# Speed: 1.2ms preprocess, 235.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.0ms
# Speed: 0.7ms preprocess, 250.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 233.7ms
# Speed: 1.3ms preprocess, 233.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 274.5ms
# Speed: 1.5ms preprocess, 274.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 249.0ms
# Speed: 1.3ms preprocess, 249.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 248.1ms
# Speed: 0.8ms preprocess, 248.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 224.2ms
# Speed: 1.2ms preprocess, 224.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 234.3ms
# Speed: 0.8ms preprocess, 234.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 256.6ms
# Speed: 2.1ms preprocess, 256.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.0ms
# Speed: 1.4ms preprocess, 252.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 231.6ms
# Speed: 1.8ms preprocess, 231.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.3ms
# Speed: 1.6ms preprocess, 250.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.3ms
# Speed: 1.5ms preprocess, 253.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.5ms
# Speed: 1.6ms preprocess, 245.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.6ms
# Speed: 1.5ms preprocess, 246.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 247.9ms
# Speed: 1.4ms preprocess, 247.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 268.1ms
# Speed: 1.5ms preprocess, 268.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 257.7ms
# Speed: 1.5ms preprocess, 257.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 301.9ms
# Speed: 1.1ms preprocess, 301.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 265.6ms
# Speed: 1.0ms preprocess, 265.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 255.0ms
# Speed: 1.2ms preprocess, 255.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.9ms
# Speed: 0.9ms preprocess, 242.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 254.1ms
# Speed: 1.9ms preprocess, 254.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 257.7ms
# Speed: 2.2ms preprocess, 257.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 259.9ms
# Speed: 1.9ms preprocess, 259.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 train, 270.8ms
# Speed: 0.9ms preprocess, 270.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.8ms
# Speed: 1.9ms preprocess, 253.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.2ms
# Speed: 2.3ms preprocess, 252.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.1ms
# Speed: 1.5ms preprocess, 253.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 244.2ms
# Speed: 1.0ms preprocess, 244.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 264.1ms
# Speed: 1.7ms preprocess, 264.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 boat, 238.4ms
# Speed: 0.8ms preprocess, 238.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 252.2ms
# Speed: 1.2ms preprocess, 252.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 260.4ms
# Speed: 1.5ms preprocess, 260.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 242.9ms
# Speed: 1.3ms preprocess, 242.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.2ms
# Speed: 0.8ms preprocess, 250.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 287.3ms
# Speed: 1.2ms preprocess, 287.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 270.0ms
# Speed: 1.2ms preprocess, 270.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 277.4ms
# Speed: 1.6ms preprocess, 277.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 259.9ms
# Speed: 1.7ms preprocess, 259.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 266.0ms
# Speed: 1.3ms preprocess, 266.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 320.0ms
# Speed: 1.0ms preprocess, 320.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 273.0ms
# Speed: 1.0ms preprocess, 273.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.3ms
# Speed: 1.4ms preprocess, 266.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.1ms
# Speed: 1.1ms preprocess, 253.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 238.3ms
# Speed: 0.9ms preprocess, 238.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 246.8ms
# Speed: 2.8ms preprocess, 246.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 256.5ms
# Speed: 1.5ms preprocess, 256.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 263.5ms
# Speed: 2.0ms preprocess, 263.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 262.8ms
# Speed: 1.5ms preprocess, 262.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 254.9ms
# Speed: 1.6ms preprocess, 254.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 245.6ms
# Speed: 0.9ms preprocess, 245.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.7ms
# Speed: 1.4ms preprocess, 253.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.1ms
# Speed: 0.9ms preprocess, 254.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 265.3ms
# Speed: 0.9ms preprocess, 265.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 278.8ms
# Speed: 1.8ms preprocess, 278.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 240.2ms
# Speed: 1.2ms preprocess, 240.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.7ms
# Speed: 0.9ms preprocess, 241.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 284.2ms
# Speed: 1.6ms preprocess, 284.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 259.7ms
# Speed: 1.8ms preprocess, 259.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 258.2ms
# Speed: 1.7ms preprocess, 258.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 280.8ms
# Speed: 1.5ms preprocess, 280.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 274.1ms
# Speed: 1.3ms preprocess, 274.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 250.6ms
# Speed: 0.9ms preprocess, 250.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 286.8ms
# Speed: 2.2ms preprocess, 286.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 330.3ms
# Speed: 1.5ms preprocess, 330.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 256.0ms
# Speed: 1.7ms preprocess, 256.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.5ms
# Speed: 1.8ms preprocess, 244.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 274.0ms
# Speed: 1.3ms preprocess, 274.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 267.6ms
# Speed: 1.0ms preprocess, 267.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 300.5ms
# Speed: 2.1ms preprocess, 300.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 268.7ms
# Speed: 1.6ms preprocess, 268.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 299.5ms
# Speed: 1.2ms preprocess, 299.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 311.6ms
# Speed: 1.7ms preprocess, 311.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 320.7ms
# Speed: 1.1ms preprocess, 320.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.6ms
# Speed: 1.0ms preprocess, 277.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 255.4ms
# Speed: 1.1ms preprocess, 255.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 258.0ms
# Speed: 0.8ms preprocess, 258.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 278.7ms
# Speed: 1.0ms preprocess, 278.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 248.7ms
# Speed: 0.9ms preprocess, 248.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 289.1ms
# Speed: 3.0ms preprocess, 289.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 259.3ms
# Speed: 1.7ms preprocess, 259.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 245.4ms
# Speed: 1.4ms preprocess, 245.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.3ms
# Speed: 0.9ms preprocess, 262.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 picket_posts, 243.1ms
# Speed: 1.6ms preprocess, 243.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.2ms
# Speed: 0.9ms preprocess, 269.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 252.8ms
# Speed: 1.1ms preprocess, 252.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.7ms
# Speed: 0.8ms preprocess, 239.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 277.0ms
# Speed: 1.5ms preprocess, 277.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 248.4ms
# Speed: 2.4ms preprocess, 248.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 272.5ms
# Speed: 1.9ms preprocess, 272.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.6ms
# Speed: 0.9ms preprocess, 254.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 274.7ms
# Speed: 1.8ms preprocess, 274.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.1ms
# Speed: 1.6ms preprocess, 244.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.4ms
# Speed: 1.1ms preprocess, 246.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 train, 1 truck, 236.6ms
# Speed: 1.0ms preprocess, 236.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 254.6ms
# Speed: 1.4ms preprocess, 254.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.6ms
# Speed: 1.2ms preprocess, 242.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 232.3ms
# Speed: 1.0ms preprocess, 232.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 255.9ms
# Speed: 0.8ms preprocess, 255.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 279.8ms
# Speed: 3.1ms preprocess, 279.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.2ms
# Speed: 1.2ms preprocess, 241.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 255.1ms
# Speed: 1.2ms preprocess, 255.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 243.3ms
# Speed: 0.9ms preprocess, 243.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.4ms
# Speed: 1.1ms preprocess, 246.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 249.7ms
# Speed: 1.2ms preprocess, 249.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 255.0ms
# Speed: 1.5ms preprocess, 255.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.1ms
# Speed: 1.7ms preprocess, 239.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 237.7ms
# Speed: 1.2ms preprocess, 237.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.6ms
# Speed: 1.0ms preprocess, 241.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 241.1ms
# Speed: 1.8ms preprocess, 241.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.9ms
# Speed: 1.4ms preprocess, 242.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 picket_posts, 282.8ms
# Speed: 4.5ms preprocess, 282.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 boat, 247.1ms
# Speed: 1.4ms preprocess, 247.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 286.1ms
# Speed: 2.1ms preprocess, 286.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.1ms
# Speed: 1.0ms preprocess, 246.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 280.1ms
# Speed: 2.3ms preprocess, 280.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 boat, 254.3ms
# Speed: 1.4ms preprocess, 254.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 241.6ms
# Speed: 1.0ms preprocess, 241.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 243.9ms
# Speed: 1.1ms preprocess, 243.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 kilometer_posts, 253.3ms
# Speed: 1.6ms preprocess, 253.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.8ms
# Speed: 1.7ms preprocess, 237.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 253.3ms
# Speed: 0.9ms preprocess, 253.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.8ms
# Speed: 1.1ms preprocess, 230.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 270.6ms
# Speed: 3.1ms preprocess, 270.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 250.3ms
# Speed: 1.5ms preprocess, 250.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 240.0ms
# Speed: 1.2ms preprocess, 240.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 238.2ms
# Speed: 1.1ms preprocess, 238.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 255.1ms
# Speed: 1.3ms preprocess, 255.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 236.8ms
# Speed: 0.9ms preprocess, 236.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 254.4ms
# Speed: 0.9ms preprocess, 254.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.2ms
# Speed: 1.1ms preprocess, 242.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 260.2ms
# Speed: 1.0ms preprocess, 260.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.1ms
# Speed: 0.9ms preprocess, 230.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 215.2ms
# Speed: 1.0ms preprocess, 215.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 226.7ms
# Speed: 1.0ms preprocess, 226.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 258.5ms
# Speed: 1.6ms preprocess, 258.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 232.3ms
# Speed: 1.6ms preprocess, 232.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 232.9ms
# Speed: 1.0ms preprocess, 232.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 237.8ms
# Speed: 1.1ms preprocess, 237.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 240.8ms
# Speed: 1.1ms preprocess, 240.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.9ms
# Speed: 0.7ms preprocess, 229.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 219.9ms
# Speed: 1.4ms preprocess, 219.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 227.2ms
# Speed: 1.8ms preprocess, 227.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 268.3ms
# Speed: 1.3ms preprocess, 268.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 231.8ms
# Speed: 1.1ms preprocess, 231.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 233.8ms
# Speed: 1.2ms preprocess, 233.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 232.0ms
# Speed: 1.0ms preprocess, 232.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 224.2ms
# Speed: 1.2ms preprocess, 224.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.4ms
# Speed: 0.8ms preprocess, 230.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 221.1ms
# Speed: 0.9ms preprocess, 221.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 233.0ms
# Speed: 0.9ms preprocess, 233.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 249.0ms
# Speed: 1.3ms preprocess, 249.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 236.2ms
# Speed: 0.8ms preprocess, 236.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 226.3ms
# Speed: 1.6ms preprocess, 226.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.8ms
# Speed: 1.7ms preprocess, 229.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 235.8ms
# Speed: 1.6ms preprocess, 235.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 230.3ms
# Speed: 0.9ms preprocess, 230.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 233.2ms
# Speed: 1.4ms preprocess, 233.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 240.8ms
# Speed: 1.0ms preprocess, 240.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 278.3ms
# Speed: 4.8ms preprocess, 278.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 228.4ms
# Speed: 1.4ms preprocess, 228.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 238.8ms
# Speed: 1.2ms preprocess, 238.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 231.7ms
# Speed: 1.2ms preprocess, 231.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 230.1ms
# Speed: 1.6ms preprocess, 230.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 275.9ms
# Speed: 0.9ms preprocess, 275.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 243.6ms
# Speed: 1.4ms preprocess, 243.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 1 boat, 248.4ms
# Speed: 1.7ms preprocess, 248.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 241.0ms
# Speed: 1.4ms preprocess, 241.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.9ms
# Speed: 1.1ms preprocess, 229.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.0ms
# Speed: 1.8ms preprocess, 246.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 234.9ms
# Speed: 1.0ms preprocess, 234.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.5ms
# Speed: 2.0ms preprocess, 273.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.9ms
# Speed: 0.9ms preprocess, 229.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 254.0ms
# Speed: 1.0ms preprocess, 254.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 248.8ms
# Speed: 1.3ms preprocess, 248.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 254.8ms
# Speed: 0.9ms preprocess, 254.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.3ms
# Speed: 1.3ms preprocess, 239.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 259.1ms
# Speed: 1.1ms preprocess, 259.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 270.5ms
# Speed: 1.2ms preprocess, 270.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.5ms
# Speed: 2.1ms preprocess, 246.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.6ms
# Speed: 1.5ms preprocess, 246.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 252.6ms
# Speed: 1.1ms preprocess, 252.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 228.3ms
# Speed: 1.1ms preprocess, 228.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 230.2ms
# Speed: 0.9ms preprocess, 230.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 233.2ms
# Speed: 0.9ms preprocess, 233.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 245.0ms
# Speed: 1.5ms preprocess, 245.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 264.1ms
# Speed: 1.8ms preprocess, 264.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 266.6ms
# Speed: 1.8ms preprocess, 266.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.4ms
# Speed: 1.4ms preprocess, 229.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 248.7ms
# Speed: 1.0ms preprocess, 248.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 236.4ms
# Speed: 1.7ms preprocess, 236.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.4ms
# Speed: 1.3ms preprocess, 273.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 251.1ms
# Speed: 0.8ms preprocess, 251.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 258.2ms
# Speed: 1.3ms preprocess, 258.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 242.9ms
# Speed: 1.5ms preprocess, 242.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 251.0ms
# Speed: 1.0ms preprocess, 251.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 242.1ms
# Speed: 1.5ms preprocess, 242.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 244.8ms
# Speed: 1.3ms preprocess, 244.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 boat, 246.0ms
# Speed: 1.8ms preprocess, 246.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 296.4ms
# Speed: 4.0ms preprocess, 296.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 269.7ms
# Speed: 1.6ms preprocess, 269.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 283.9ms
# Speed: 2.2ms preprocess, 283.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 291.2ms
# Speed: 0.9ms preprocess, 291.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 275.7ms
# Speed: 1.1ms preprocess, 275.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 270.4ms
# Speed: 0.9ms preprocess, 270.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 269.5ms
# Speed: 3.7ms preprocess, 269.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.6ms
# Speed: 1.3ms preprocess, 254.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 274.9ms
# Speed: 1.2ms preprocess, 274.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.6ms
# Speed: 1.0ms preprocess, 246.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 237.8ms
# Speed: 1.3ms preprocess, 237.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.9ms
# Speed: 0.8ms preprocess, 237.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 237.6ms
# Speed: 1.4ms preprocess, 237.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.1ms
# Speed: 1.0ms preprocess, 239.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 303.7ms
# Speed: 3.4ms preprocess, 303.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 241.9ms
# Speed: 1.0ms preprocess, 241.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 picket_posts, 260.3ms
# Speed: 1.5ms preprocess, 260.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 257.1ms
# Speed: 1.1ms preprocess, 257.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 233.0ms
# Speed: 1.3ms preprocess, 233.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 229.0ms
# Speed: 1.5ms preprocess, 229.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 235.8ms
# Speed: 0.9ms preprocess, 235.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 241.4ms
# Speed: 1.1ms preprocess, 241.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 259.7ms
# Speed: 1.1ms preprocess, 259.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 236.0ms
# Speed: 0.9ms preprocess, 236.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 269.0ms
# Speed: 2.9ms preprocess, 269.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 257.4ms
# Speed: 1.7ms preprocess, 257.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 244.7ms
# Speed: 1.0ms preprocess, 244.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 244.5ms
# Speed: 1.1ms preprocess, 244.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 259.0ms
# Speed: 1.3ms preprocess, 259.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.4ms
# Speed: 1.0ms preprocess, 254.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 232.5ms
# Speed: 0.9ms preprocess, 232.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.1ms
# Speed: 0.7ms preprocess, 252.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 300.2ms
# Speed: 0.9ms preprocess, 300.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.0ms
# Speed: 1.1ms preprocess, 277.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 292.1ms
# Speed: 3.5ms preprocess, 292.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.0ms
# Speed: 0.8ms preprocess, 252.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 290.3ms
# Speed: 1.0ms preprocess, 290.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 257.2ms
# Speed: 0.7ms preprocess, 257.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 235.5ms
# Speed: 1.3ms preprocess, 235.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 237.8ms
# Speed: 0.9ms preprocess, 237.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 263.4ms
# Speed: 2.2ms preprocess, 263.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 258.8ms
# Speed: 0.8ms preprocess, 258.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 250.2ms
# Speed: 0.9ms preprocess, 250.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 246.4ms
# Speed: 1.2ms preprocess, 246.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 256.7ms
# Speed: 1.6ms preprocess, 256.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 246.4ms
# Speed: 1.6ms preprocess, 246.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 238.9ms
# Speed: 1.2ms preprocess, 238.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.3ms
# Speed: 1.2ms preprocess, 266.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 240.0ms
# Speed: 1.1ms preprocess, 240.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.1ms
# Speed: 0.9ms preprocess, 251.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 244.9ms
# Speed: 2.4ms preprocess, 244.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 239.3ms
# Speed: 1.5ms preprocess, 239.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 229.0ms
# Speed: 1.8ms preprocess, 229.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.2ms
# Speed: 1.3ms preprocess, 245.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 263.0ms
# Speed: 2.4ms preprocess, 263.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.7ms
# Speed: 1.7ms preprocess, 251.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 257.3ms
# Speed: 1.7ms preprocess, 257.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 266.4ms
# Speed: 1.7ms preprocess, 266.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 306.3ms
# Speed: 2.1ms preprocess, 306.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.4ms
# Speed: 0.9ms preprocess, 246.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 303.0ms
# Speed: 2.0ms preprocess, 303.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 279.3ms
# Speed: 1.4ms preprocess, 279.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 243.8ms
# Speed: 1.0ms preprocess, 243.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.2ms
# Speed: 1.2ms preprocess, 246.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 249.1ms
# Speed: 1.1ms preprocess, 249.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 263.9ms
# Speed: 1.1ms preprocess, 263.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 239.1ms
# Speed: 1.0ms preprocess, 239.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 240.6ms
# Speed: 0.8ms preprocess, 240.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 269.1ms
# Speed: 6.3ms preprocess, 269.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 boat, 247.6ms
# Speed: 1.5ms preprocess, 247.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 256.3ms
# Speed: 1.2ms preprocess, 256.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 239.0ms
# Speed: 1.6ms preprocess, 239.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 260.4ms
# Speed: 1.1ms preprocess, 260.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 239.6ms
# Speed: 1.1ms preprocess, 239.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.2ms
# Speed: 1.2ms preprocess, 273.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.0ms
# Speed: 0.8ms preprocess, 252.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 457.1ms
# Speed: 2.0ms preprocess, 457.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 299.7ms
# Speed: 1.1ms preprocess, 299.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 406.5ms
# Speed: 0.8ms preprocess, 406.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 386.7ms
# Speed: 1.2ms preprocess, 386.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 327.6ms
# Speed: 1.7ms preprocess, 327.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 281.8ms
# Speed: 2.0ms preprocess, 281.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 448.9ms
# Speed: 1.8ms preprocess, 448.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 288.2ms
# Speed: 1.2ms preprocess, 288.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 419.7ms
# Speed: 2.4ms preprocess, 419.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 326.4ms
# Speed: 3.7ms preprocess, 326.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 390.3ms
# Speed: 3.5ms preprocess, 390.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 287.9ms
# Speed: 0.9ms preprocess, 287.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 497.6ms
# Speed: 2.5ms preprocess, 497.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 344.0ms
# Speed: 2.1ms preprocess, 344.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 401.2ms
# Speed: 2.3ms preprocess, 401.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 389.1ms
# Speed: 1.2ms preprocess, 389.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 399.2ms
# Speed: 4.0ms preprocess, 399.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 348.4ms
# Speed: 1.7ms preprocess, 348.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 409.9ms
# Speed: 1.3ms preprocess, 409.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 358.4ms
# Speed: 2.0ms preprocess, 358.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 390.7ms
# Speed: 1.9ms preprocess, 390.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 521.6ms
# Speed: 2.1ms preprocess, 521.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 401.0ms
# Speed: 1.3ms preprocess, 401.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 410.0ms
# Speed: 1.4ms preprocess, 410.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 348.9ms
# Speed: 3.4ms preprocess, 348.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 510.1ms
# Speed: 1.7ms preprocess, 510.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 435.0ms
# Speed: 1.8ms preprocess, 435.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 316.4ms
# Speed: 1.2ms preprocess, 316.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 547.3ms
# Speed: 1.5ms preprocess, 547.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 457.0ms
# Speed: 1.3ms preprocess, 457.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 407.0ms
# Speed: 2.8ms preprocess, 407.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 357.9ms
# Speed: 5.9ms preprocess, 357.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 594.9ms
# Speed: 2.5ms preprocess, 594.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 359.0ms
# Speed: 1.9ms preprocess, 359.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 645.6ms
# Speed: 5.6ms preprocess, 645.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 491.8ms
# Speed: 3.6ms preprocess, 491.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 264.2ms
# Speed: 1.3ms preprocess, 264.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 388.7ms
# Speed: 1.3ms preprocess, 388.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 347.6ms
# Speed: 1.8ms preprocess, 347.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 245.5ms
# Speed: 1.0ms preprocess, 245.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 464.1ms
# Speed: 1.7ms preprocess, 464.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 358.7ms
# Speed: 3.8ms preprocess, 358.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 283.9ms
# Speed: 1.0ms preprocess, 283.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 298.1ms
# Speed: 1.3ms preprocess, 298.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 708.7ms
# Speed: 2.2ms preprocess, 708.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 371.2ms
# Speed: 1.9ms preprocess, 371.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 444.1ms
# Speed: 1.7ms preprocess, 444.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 301.3ms
# Speed: 0.9ms preprocess, 301.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 383.9ms
# Speed: 1.3ms preprocess, 383.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 508.3ms
# Speed: 1.2ms preprocess, 508.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 384.5ms
# Speed: 1.6ms preprocess, 384.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 527.6ms
# Speed: 2.5ms preprocess, 527.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 418.5ms
# Speed: 1.0ms preprocess, 418.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 447.0ms
# Speed: 2.7ms preprocess, 447.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 362.4ms
# Speed: 2.0ms preprocess, 362.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 457.6ms
# Speed: 0.9ms preprocess, 457.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 446.1ms
# Speed: 1.5ms preprocess, 446.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 378.0ms
# Speed: 0.8ms preprocess, 378.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 435.2ms
# ...
#
# 0: 384x640 1 picket_post, 286.0ms
# Speed: 2.1ms preprocess, 286.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.2ms
# Speed: 0.9ms preprocess, 246.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 272.8ms
# Speed: 1.7ms preprocess, 272.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.4ms
# Speed: 1.9ms preprocess, 262.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 255.3ms
# Speed: 0.9ms preprocess, 255.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 2 boats, 252.5ms
# Speed: 1.0ms preprocess, 252.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 246.4ms
# Speed: 1.9ms preprocess, 246.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 246.4ms
# Speed: 1.5ms preprocess, 246.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 280.0ms
# Speed: 4.3ms preprocess, 280.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.4ms
# Speed: 1.6ms preprocess, 266.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 257.8ms
# Speed: 1.2ms preprocess, 257.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.5ms
# Speed: 1.0ms preprocess, 254.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.7ms
# Speed: 0.9ms preprocess, 273.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 277.3ms
# Speed: 1.3ms preprocess, 277.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.2ms
# Speed: 1.0ms preprocess, 273.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 1 traffic light, 257.0ms
# Speed: 0.8ms preprocess, 257.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 273.5ms
# Speed: 1.3ms preprocess, 273.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 251.0ms
# Speed: 1.1ms preprocess, 251.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 272.5ms
# Speed: 3.1ms preprocess, 272.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.4ms
# Speed: 1.6ms preprocess, 262.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 310.2ms
# Speed: 2.0ms preprocess, 310.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 282.4ms
# Speed: 1.7ms preprocess, 282.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 298.4ms
# Speed: 1.6ms preprocess, 298.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 288.5ms
# Speed: 1.9ms preprocess, 288.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 307.7ms
# Speed: 1.1ms preprocess, 307.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 291.5ms
# Speed: 1.1ms preprocess, 291.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 289.9ms
# Speed: 1.1ms preprocess, 289.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 trains, 275.7ms
# Speed: 1.3ms preprocess, 275.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 275.0ms
# Speed: 1.4ms preprocess, 275.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 290.0ms
# Speed: 0.8ms preprocess, 290.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 296.7ms
# Speed: 1.1ms preprocess, 296.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 252.8ms
# Speed: 1.1ms preprocess, 252.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 282.5ms
# Speed: 0.9ms preprocess, 282.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 259.6ms
# Speed: 0.9ms preprocess, 259.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 255.9ms
# Speed: 0.9ms preprocess, 255.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 266.5ms
# Speed: 1.1ms preprocess, 266.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 275.1ms
# Speed: 1.0ms preprocess, 275.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 249.2ms
# Speed: 0.8ms preprocess, 249.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 540.6ms
# Speed: 1.2ms preprocess, 540.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 442.7ms
# Speed: 0.9ms preprocess, 442.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 515.5ms
# Speed: 8.2ms preprocess, 515.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 573.9ms
# Speed: 1.3ms preprocess, 573.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 489.4ms
# Speed: 6.1ms preprocess, 489.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 631.7ms
# Speed: 2.0ms preprocess, 631.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 516.9ms
# Speed: 4.6ms preprocess, 516.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 427.2ms
# Speed: 2.4ms preprocess, 427.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 479.1ms
# Speed: 11.9ms preprocess, 479.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 316.9ms
# Speed: 1.8ms preprocess, 316.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 657.4ms
# Speed: 2.7ms preprocess, 657.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 514.4ms
# Speed: 8.6ms preprocess, 514.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 675.0ms
# Speed: 3.1ms preprocess, 675.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 365.5ms
# Speed: 1.8ms preprocess, 365.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 442.3ms
# Speed: 1.6ms preprocess, 442.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 302.2ms
# Speed: 1.0ms preprocess, 302.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 703.2ms
# Speed: 1.9ms preprocess, 703.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 396.6ms
# Speed: 1.8ms preprocess, 396.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 445.1ms
# Speed: 2.6ms preprocess, 445.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 487.2ms
# Speed: 2.3ms preprocess, 487.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 386.2ms
# Speed: 1.9ms preprocess, 386.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 322.1ms
# Speed: 1.3ms preprocess, 322.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 563.6ms
# Speed: 1.2ms preprocess, 563.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 466.0ms
# Speed: 4.0ms preprocess, 466.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 550.9ms
# Speed: 3.8ms preprocess, 550.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 662.7ms
# Speed: 2.8ms preprocess, 662.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 308.7ms
# Speed: 1.6ms preprocess, 308.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 262.0ms
# Speed: 1.4ms preprocess, 262.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 386.5ms
# Speed: 1.9ms preprocess, 386.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 280.7ms
# Speed: 0.8ms preprocess, 280.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 307.7ms
# Speed: 1.6ms preprocess, 307.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 468.1ms
# Speed: 1.0ms preprocess, 468.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 463.1ms
# Speed: 2.9ms preprocess, 463.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 276.2ms
# Speed: 1.1ms preprocess, 276.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 661.0ms
# Speed: 2.0ms preprocess, 661.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 349.9ms
# Speed: 1.7ms preprocess, 349.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 685.8ms
# Speed: 4.3ms preprocess, 685.8ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 579.3ms
# Speed: 7.4ms preprocess, 579.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 576.6ms
# Speed: 1.7ms preprocess, 576.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 490.2ms
# Speed: 1.1ms preprocess, 490.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 371.6ms
# Speed: 2.3ms preprocess, 371.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 boat, 612.6ms
# Speed: 1.0ms preprocess, 612.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 382.3ms
# Speed: 4.6ms preprocess, 382.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 416.0ms
# Speed: 1.6ms preprocess, 416.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 341.4ms
# Speed: 10.8ms preprocess, 341.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 254.3ms
# Speed: 1.3ms preprocess, 254.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 361.8ms
# Speed: 11.0ms preprocess, 361.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 282.6ms
# Speed: 1.3ms preprocess, 282.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 503.6ms
# Speed: 1.2ms preprocess, 503.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 332.0ms
# Speed: 1.0ms preprocess, 332.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 664.3ms
# Speed: 1.7ms preprocess, 664.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 493.9ms
# Speed: 1.4ms preprocess, 493.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 426.6ms
# Speed: 3.3ms preprocess, 426.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 453.9ms
# Speed: 2.1ms preprocess, 453.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 278.8ms
# Speed: 1.3ms preprocess, 278.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 275.9ms
# Speed: 0.9ms preprocess, 275.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 612.4ms
# Speed: 1.8ms preprocess, 612.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 276.3ms
# Speed: 1.6ms preprocess, 276.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 457.6ms
# Speed: 1.6ms preprocess, 457.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 715.1ms
# Speed: 1.2ms preprocess, 715.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 440.1ms
# Speed: 2.3ms preprocess, 440.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 316.6ms
# Speed: 1.1ms preprocess, 316.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 542.7ms
# Speed: 5.1ms preprocess, 542.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 621.0ms
# Speed: 1.3ms preprocess, 621.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 469.5ms
# Speed: 2.4ms preprocess, 469.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 trains, 1 traffic light, 365.9ms
# Speed: 1.5ms preprocess, 365.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 518.8ms
# Speed: 1.8ms preprocess, 518.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 466.5ms
# Speed: 1.6ms preprocess, 466.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 491.7ms
# Speed: 2.5ms preprocess, 491.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 448.1ms
# Speed: 2.4ms preprocess, 448.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 364.1ms
# Speed: 3.3ms preprocess, 364.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 345.9ms
# Speed: 1.3ms preprocess, 345.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 469.7ms
# Speed: 2.2ms preprocess, 469.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 352.2ms
# Speed: 0.8ms preprocess, 352.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 picket_post, 334.2ms
# Speed: 2.8ms preprocess, 334.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 290.0ms
# Speed: 1.3ms preprocess, 290.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 379.1ms
# Speed: 2.2ms preprocess, 379.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 train, 379.0ms
# Speed: 1.0ms preprocess, 379.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 kilometer_post, 446.4ms
# Speed: 1.3ms preprocess, 446.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 traffic light, 522.4ms
# Speed: 4.2ms preprocess, 522.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Cell 6: Инференс на подвыборке выполнен.
#   Количество изображений: 500

# %%
# Cell 7: Вычисление метрик и сравнение
# mAP@0.5 для первой модели
ap_per_class_1, mAP_1 = compute_map(all_gt, all_preds_1, iou_threshold=0.5)
# mAP@0.5 для второй модели
ap_per_class_2, mAP_2 = compute_map(all_gt, all_preds_2, iou_threshold=0.5)

print("Cell 7: Результаты оценки:")
print(f"  Model 1 (best.pt) mAP@0.5 = {mAP_1:.4f}")
print(f"  Model 2 (yolo12m.pt) mAP@0.5 = {mAP_2:.4f}")

# Вывод AP по классам (опционально, если классов немного)
print("\nAP по классам (Model 1):")
for cls_id, ap in sorted(ap_per_class_1.items()):
    print(f"  Class {cls_id}: AP = {ap:.4f}")

print("\nAP по классам (Model 2):")
for cls_id, ap in sorted(ap_per_class_2.items()):
    print(f"  Class {cls_id}: AP = {ap:.4f}")

# Простой вывод: какая модель лучше по mAP
if mAP_1 > mAP_2:
    print("\nВывод: Model 1 (best.pt) показала лучшие результаты.")
elif mAP_2 > mAP_1:
    print("\nВывод: Model 2 (yolo12m.pt) показала лучшие результаты.")
else:
    print("\nВывод: Оба модели показали одинаковый mAP@0.5.")
# Out:
# Cell 7: Результаты оценки:
#   Model 1 (best.pt) mAP@0.5 = 0.8554
#   Model 2 (yolo12m.pt) mAP@0.5 = 0.0000
#
# AP по классам (Model 1):
#   Class 0: AP = 0.7877
#   Class 1: AP = 0.9230
#
# AP по классам (Model 2):
#   Class 0: AP = 0.0000
#   Class 1: AP = 0.0000
#   Class 2: AP = 0.0000
#   Class 6: AP = 0.0000
#   Class 7: AP = 0.0000
#   Class 8: AP = 0.0000
#   Class 9: AP = 0.0000
#
# Вывод: Model 1 (best.pt) показала лучшие результаты.

# %%
# Cell 8 (опционально): Сохранение результатов в DataFrame и CSV
results = {
    'class_id': [],
    'AP_model1': [],
    'AP_model2': []
}
all_classes = set(ap_per_class_1.keys()).union(set(ap_per_class_2.keys()))
for cls in sorted(all_classes):
    results['class_id'].append(cls)
    results['AP_model1'].append(ap_per_class_1.get(cls, 0.0))
    results['AP_model2'].append(ap_per_class_2.get(cls, 0.0))

df_results = pd.DataFrame(results)
df_results['diff_AP'] = df_results['AP_model2'] - df_results['AP_model1']

# Добавим строку с общим mAP
df_summary = pd.DataFrame([{
    'class_id': 'mAP@0.5',
    'AP_model1': mAP_1,
    'AP_model2': mAP_2,
    'diff_AP': mAP_2 - mAP_1
}])
df_out = pd.concat([df_results, df_summary], ignore_index=True)

# Сохраним в CSV рядом с ноутбуком
output_path = os.path.join(project_root, 'training', 'comparsion', 'yolo_comparison_results.csv')
os.makedirs(os.path.dirname(output_path), exist_ok=True)
df_out.to_csv(output_path, index=False)

print(f"Cell 8: Результаты сохранены в {output_path}")
df_out.head(10)
# Out:
# Cell 8: Результаты сохранены в c:\Users\thjat\ml-system-design-aith\training\comparsion\yolo_comparison_results.csv
#   class_id  AP_model1  AP_model2   diff_AP
# 0        0   0.787745        0.0 -0.787745
# 1        1   0.923024        0.0 -0.923024
# 2        2   0.000000        0.0  0.000000
# 3        6   0.000000        0.0  0.000000
# 4        7   0.000000        0.0  0.000000
# 5        8   0.000000        0.0  0.000000
# 6        9   0.000000        0.0  0.000000
# 7  mAP@0.5   0.855385        0.0 -0.855385
